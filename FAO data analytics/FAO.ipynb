# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 

fao= pd.read_csv("FAOSTAT.csv")
fao.head()
fao.describe()
# Out:
#        Area Code (FAO)   Element Code      Item Code     Year Code  Note
# count    120698.000000  120698.000000  120698.000000  1.206980e+05   0.0
# mean        129.006206    6126.148130   63623.580540  7.181792e+06   NaN
# std          75.774948       9.522529   78951.034606  9.628340e+06   NaN
# min           1.000000    6121.000000   21010.000000  2.000000e+03   NaN
# 25%          63.000000    6121.000000   21032.000000  2.007000e+03   NaN
# 50%         126.000000    6123.000000   21047.000000  2.015000e+03   NaN
# 75%         193.000000    6128.000000   22013.000000  2.005201e+07   NaN
# max         351.000000    6173.000000  210490.000000  2.018202e+07   NaN

# %%
fao.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120698 entries, 0 to 120697
# Data columns (total 15 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Domain Code       120698 non-null  object
#  1   Domain            120698 non-null  object
#  2   Area Code (FAO)   120698 non-null  int64
#  3   Area              120698 non-null  object
#  4   Element Code      120698 non-null  int64
#  5   Element           120698 non-null  object
#  6   Item Code         120698 non-null  int64
#  7   Item              120698 non-null  object
#  8   Year Code         120698 non-null  int64
#  9   Year              120698 non-null  object
#  10  Unit              120698 non-null  object
#  11  Value             116267 non-null  object
#  12  Flag              120698 non-null  object
#  13  Flag Description  120698 non-null  object
#  14  Note              0 non-null       float64
# dtypes: float64(1), int64(4), object(10)
# ...

# %%
fao.shape
# Out:
# (120698, 15)

# %%
fao.nunique()
# Out:
# Domain Code            1
# Domain                 1
# Area Code (FAO)      204
# Area                 204
# Element Code          10
# Element                1
# Item Code             42
# Item                  42
# Year Code             40
# Year                  40
# Unit                  10
# Value               8950
# Flag                   4
# Flag Description       4
# Note                   0
# dtype: int64

# %%
fao.columns
# Out:
# Index(['Domain Code', 'Domain', 'Area Code (FAO)', 'Area', 'Element Code',
#        'Element', 'Item Code', 'Item', 'Year Code', 'Year', 'Unit', 'Value',
#        'Flag', 'Flag Description', 'Note'],
#       dtype='object')

# %%
fao.isnull().sum()
# Out:
# Domain Code              0
# Domain                   0
# Area Code (FAO)          0
# Area                     0
# Element Code             0
# Element                  0
# Item Code                0
# Item                     0
# Year Code                0
# Year                     0
# Unit                     0
# Value                 4431
# Flag                     0
# Flag Description         0
# Note                120698
# dtype: int64

# %%
fao_drop=fao.drop(["Value","Note"],axis=1)

# %%
fao_drop.isnull().sum()
# Out:
# Domain Code         0
# Domain              0
# Area Code (FAO)     0
# Area                0
# Element Code        0
# Element             0
# Item Code           0
# Item                0
# Year Code           0
# Year                0
# Unit                0
# Flag                0
# Flag Description    0
# dtype: int64

# %%
fao_drop.dropna()
fao_drop.shape
# Out:
# (120698, 13)

# %%
fao_drop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120698 entries, 0 to 120697
# Data columns (total 14 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Domain Code       120698 non-null  object
#  1   Domain            120698 non-null  object
#  2   Area Code (FAO)   120698 non-null  int64
#  3   Area              120698 non-null  object
#  4   Element Code      120698 non-null  int64
#  5   Element           120698 non-null  object
#  6   Item Code         120698 non-null  int64
#  7   Item              120698 non-null  object
#  8   Year Code         120698 non-null  int64
#  9   Year              120698 non-null  object
#  10  Unit              120698 non-null  object
#  11  Flag              120698 non-null  object
#  12  Flag Description  120698 non-null  object
#  13  Note              0 non-null       float64
# dtypes: float64(1), int64(4), object(9)
# memory usage: 12.9+ MB

# %%
fao_drop.shape
# Out:
# (120698, 13)

# %%
fao.shape
# Out:
# (120698, 15)

# %%
fao_drop["Flag"].value_counts()
# Out:
# F     61481
# X     54808
# NV     2826
# NR     1583
# Name: Flag, dtype: int64

# %%
fao_drop.describe()
# Out:
#        Area Code (FAO)   Element Code      Item Code     Year Code
# count    120698.000000  120698.000000  120698.000000  1.206980e+05
# mean        129.006206    6126.148130   63623.580540  7.181792e+06
# std          75.774948       9.522529   78951.034606  9.628340e+06
# min           1.000000    6121.000000   21010.000000  2.000000e+03
# 25%          63.000000    6121.000000   21032.000000  2.007000e+03
# 50%         126.000000    6123.000000   21047.000000  2.015000e+03
# 75%         193.000000    6128.000000   22013.000000  2.005201e+07
# max         351.000000    6173.000000  210490.000000  2.018202e+07

# %%
fao_drop.columns
# Out:
# Index(['Domain Code', 'Domain', 'Area Code (FAO)', 'Area', 'Element Code',
#        'Element', 'Item Code', 'Item', 'Year Code', 'Year', 'Unit', 'Flag',
#        'Flag Description'],
#       dtype='object')

# %%
sns.boxplot(y="Item",data=fao_drop,axis=1)
plt.show()

# %%
sns.displot(fao_drop["Flag"])

# %%
fao_drop.boxplot()
# Out:
# <AxesSubplot:>

# %%
sns.distplot(fao_drop["Year Code"])
fao_drop["Year Code"]=np.log(fao_drop["Year Code"])
fao_drop.head()
# Out:
# C:\Users\issa\AppData\Local\Programs\Python\Python38\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
#   Domain Code                             Domain  Area Code (FAO)  \
# 0          FS  Suite of Food Security Indicators                2
# 1          FS  Suite of Food Security Indicators                2
# 2          FS  Suite of Food Security Indicators                2
# 3          FS  Suite of Food Security Indicators                2
# 4          FS  Suite of Food Security Indicators                2
#
#           Area  Element Code Element  Item Code  \
# 0  Afghanistan          6121   Value      21010
# 1  Afghanistan          6121   Value      21010
# ...

# %%
fao_drop.boxplot()
# Out:
# <AxesSubplot:>

# %%
fao_drop.groupby(["Item"]).mean().plot.bar()
# Out:
# <AxesSubplot:xlabel='Item'>

# %%
fao_drop.corr().plot.bar()
# Out:
# <AxesSubplot:>

# %%
fao_drop_clean=fao_drop.corr()
sns.heatmap(fao_drop_clean)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(fao_drop_clean,annot=True)
# Out:
# <AxesSubplot:>
